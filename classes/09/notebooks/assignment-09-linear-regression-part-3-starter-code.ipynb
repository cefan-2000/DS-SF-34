# %% [markdown]
# # DS-SF-34 | 09 | Linear Regression, Part 3 | Assignment | Starter Code

# %%
import os

import pandas as pd
pd.set_option('display.max_rows', 15)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

from sklearn import feature_selection, linear_model

import statsmodels.formula.api as smf

# %%
df = pd.read_csv(os.path.join('..', 'datasets', 'dataset-09-credit.csv'))

# %%
df
# Out:
#       Income  Rating  Cards  Age  Education  Gender Student Married  \
# 0     14.891     283      2   34         11    Male      No     Yes
# 1    106.025     483      3   82         15  Female     Yes     Yes
# 2    104.593     514      4   71         11    Male      No      No
# 3    148.924     681      3   36         11  Female      No      No
# 4     55.882     357      2   68         16    Male      No     Yes
# ..       ...     ...    ...  ...        ...     ...     ...     ...
# 395   12.096     307      3   32         13    Male      No     Yes
# 396   13.364     296      5   65         17    Male      No      No
# 397   57.872     321      5   67         12  Female      No     Yes
# 398   37.728     192      1   44         13    Male      No     Yes
# 399   18.701     415      5   64          7  Female      No      No
#
#             Ethnicity  Balance
# 0           Caucasian      333
# 1               Asian      903
# 2               Asian      580
# 3               Asian      964
# 4           Caucasian      331
# ..                ...      ...
# 395         Caucasian      560
# 396  African American      480
# 397         Caucasian      138
# 398         Caucasian        0
# 399             Asian      966
#
# [400 rows x 10 columns]

# %% [markdown]
# A description of the dataset is as follows:
#
# - Income (in thousands of dollars)
# - Rating: Credit score rating
# - Cards: Number of credit cards owned
# - Age
# - Education: Years of education
# - Gender: Male/Female
# - Student: Yes/No
# - Married: Yes/No
# - Ethnicity: African American/Asian/Caucasian
# - Balance: Average credit card debt

# %% [markdown]
# > ## Question 1.  Let's explore the quantitative variables that affect `Balance`.  From your preliminary analysis, which 2 variables seem to affect `Balance` the most?  Our goal is interpretation; can we use these 2 variables simultaneously?  Why or why not?

# %%
# TODO
df.corr()
# from the correlation matrix, balance is most linearly related to rating and income.  
#But Rating and Income are pretty closely related, so we should use only one.
# Out:
#              Income    Rating     Cards       Age  Education   Balance
# Income     1.000000  0.791378 -0.018273  0.175338  -0.027692  0.463656
# Rating     0.791378  1.000000  0.053239  0.103165  -0.030136  0.863625
# Cards     -0.018273  0.053239  1.000000  0.042948  -0.051084  0.086456
# Age        0.175338  0.103165  0.042948  1.000000   0.003619  0.001835
# Education -0.027692 -0.030136 -0.051084  0.003619   1.000000 -0.008062
# Balance    0.463656  0.863625  0.086456  0.001835  -0.008062  1.000000

# %% [markdown]
# Answer: TODO

# %% [markdown]
# > ## Question 2.  `Ethnicity`, `Gender`, `Married`, and `Student` are categorical variables.  Go ahead and create dummy variables for all of them.

# %%
# TODO
eth_df = pd.get_dummies(df.Ethnicity, prefix = 'Eth')
eth_df.rename(columns = {'Eth_African American': 'Af_Am',
    'Eth_Asian': 'Asian',
    'Eth_Caucasian': 'Caucasian'}, inplace = True)
df = df.join([eth_df]) 

df['Male']=0
df['Male']=(df.Gender=='Male')*1.
df[['Gender','Male']]

df['IsMarried']=0
df['IsMarried']=(df.Married=='Yes')*1.
df[['Married','IsMarried']]

df['IsStudent']=0
df['IsStudent']=(df.Student=='Yes')*1.
df[['Student','IsStudent']]

df
# Out:
#       Income  Rating  Cards  Age  Education    ...     Asian Caucasian Male  \
# 0     14.891     283      2   34         11    ...         0         1  1.0
# 1    106.025     483      3   82         15    ...         1         0  0.0
# 2    104.593     514      4   71         11    ...         1         0  1.0
# 3    148.924     681      3   36         11    ...         1         0  0.0
# 4     55.882     357      2   68         16    ...         0         1  1.0
# 5     80.180     569      4   77         10    ...         0         1  1.0
# 6     20.996     259      2   37         12    ...         0         0  0.0
# ..       ...     ...    ...  ...        ...    ...       ...       ...  ...
# 393   17.316     138      2   65         13    ...         0         0  1.0
# 394   49.794     410      4   40          8    ...         0         1  1.0
# 395   12.096     307      3   32         13    ...         0         1  1.0
# 396   13.364     296      5   65         17    ...         0         0  1.0
# 397   57.872     321      5   67         12    ...         0         1  0.0
# 398   37.728     192      1   44         13    ...         0         1  1.0
# 399   18.701     415      5   64          7    ...         1         0  0.0
#
#     IsMarried  IsStudent
# 0         1.0        0.0
# 1         1.0        1.0
# 2         0.0        0.0
# 3         0.0        0.0
# 4         1.0        0.0
# 5         0.0        0.0
# 6         0.0        0.0
# ..        ...        ...
# 393       0.0        0.0
# 394       0.0        0.0
# 395       1.0        0.0
# 396       0.0        0.0
# 397       1.0        0.0
# 398       1.0        0.0
# 399       0.0        0.0
#
# [400 rows x 16 columns]

# %% [markdown]
# > ## Question 3.  Using _sklearn_'s linear regression, predict `Balance` using `Income`, `Cards`, `Age`, `Education`, `Gender`, and `Ethnicity`

# %% [markdown]
# First, find the coefficients of your regression line.

# %%
# TODO
model = smf.ols(formula = 'Balance ~ Income + Cards + Age + Education + Male + Asian + Caucasian', data = df).fit()
model.summary()
# WHY DO I GET A DIFFERENT P VALUE FOR THIS REGRESSION COMPARED TO ONE IN SOLUTION?!?!?
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Balance   R-squared:                       0.232
# Model:                            OLS   Adj. R-squared:                  0.219
# Method:                 Least Squares   F-statistic:                     16.95
# Date:                Sun, 21 May 2017   Prob (F-statistic):           1.41e-19
# Time:                        14:32:21   Log-Likelihood:                -2966.5
# No. Observations:                 400   AIC:                             5949.
# Df Residuals:                     392   BIC:                             5981.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    257.1678    129.741      1.982      0.048         2.092   512.243
# Income         6.2800      0.587     10.696      0.000         5.126     7.434
# Cards         33.6295     14.881      2.260      0.024         4.373    62.887
# Age           -2.3297      1.202     -1.938      0.053        -4.694     0.034
# Education      1.6455      6.527      0.252      0.801       -11.187    14.478
# Male         -27.1254     40.695     -0.667      0.505      -107.134    52.883
# Asian         -6.5460     57.531     -0.114      0.909      -119.654   106.562
# Caucasian      3.4750     50.071      0.069      0.945       -94.967   101.917
# ==============================================================================
# Omnibus:                       36.209   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.357
# Skew:                           0.349   Prob(JB):                     0.000103
# Kurtosis:                       2.216   Cond. No.                         510.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Then, find the p-values of your F-values' models.  You have a few variables, so try to show your p-values alongside the names of the variables.  (https://docs.python.org/2/library/functions.html#zip)

# %%
# TODO

# %% [markdown]
# > ## Question 4.  Which of your coefficients are significant at the 5% significance level?

# %% [markdown]
# Answer: TODO
# Intercept
# Income
# Cards

# %% [markdown]
# > ## Question 5.  What is your model's $R^2$?

# %%
# TODO
.232

# %% [markdown]
# > ## Question 6.  How do we interpret this value?

# %% [markdown]
# Answer: TODO
# Closer to 1 is better.  23% OF THE VARIABILITY IS CAPTURED BY INTERCEPT, INCOME, AND CARDS.

# %% [markdown]
# > ## Question 7.  Now let's focus on the two most significant variables from your previous model and re-run your regression model.

# %%
# TODO
model = smf.ols(formula = 'Balance ~ Income + Cards', data = df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Balance   R-squared:                       0.224
# Model:                            OLS   Adj. R-squared:                  0.220
# Method:                 Least Squares   F-statistic:                     57.30
# Date:                Sat, 20 May 2017   Prob (F-statistic):           1.38e-22
# Time:                        17:10:48   Log-Likelihood:                -2968.6
# No. Observations:                 400   AIC:                             5943.
# Df Residuals:                     397   BIC:                             5955.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    151.3299     55.289      2.737      0.006        42.634   260.026
# Income         6.0710      0.577     10.525      0.000         4.937     7.205
# Cards         31.8381     14.826      2.147      0.032         2.691    60.985
# ==============================================================================
# Omnibus:                       39.698   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.444
# Skew:                           0.359   Prob(JB):                     5.99e-05
# Kurtosis:                       2.194   Cond. No.                         160.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# > ## Question 8.  In comparison to the previous model, did the $R^2$ increase or decrease?  Why?

# %%
# TODO
R2 decreased, but adjusted R2 increased slightly.

# %% [markdown]
# Answer: TODO

# %% [markdown]
# > ## Question 9.  Now let's regress `Balance` on `Gender` alone.  After running your linear regressions, do you have enough evidence to claim that females have more balance than males?  (Hint: Look at the p-value of the Gender coefficient.  If it is significant then you will have evidence to support that claim, otherwise you cannot support the statement.)

# %%
# TODO
model = smf.ols(formula = 'Balance ~ Male', data = df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Balance   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.1836
# Date:                Sat, 20 May 2017   Prob (F-statistic):              0.669
# Time:                        17:11:52   Log-Likelihood:                -3019.3
# No. Observations:                 400   AIC:                             6043.
# Df Residuals:                     398   BIC:                             6051.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    529.5362     31.988     16.554      0.000       466.649   592.423
# Male         -19.7331     46.051     -0.429      0.669      -110.267    70.801
# ==============================================================================
# Omnibus:                       28.438   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.346
# Skew:                           0.583   Prob(JB):                     1.15e-06
# Kurtosis:                       2.471   Cond. No.                         2.58
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Answer: (If your answer is yes, interpret the results).  TODO

# %% [markdown]
# > ## Question 10.  Now let's regress `Balance` on `Ethnicity`.  After running your linear regressions, do you have enough evidence to claim that some ethnic groups carry more balance than others?

# %%
# TODO
model = smf.ols(formula = 'Balance ~ Asian + Caucasian', data = df).fit()
model.summary()

# no, coefficients are not significant
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Balance   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                   0.04344
# Date:                Sat, 20 May 2017   Prob (F-statistic):              0.957
# Time:                        17:12:20   Log-Likelihood:                -3019.3
# No. Observations:                 400   AIC:                             6045.
# Df Residuals:                     397   BIC:                             6057.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    531.0000     46.319     11.464      0.000       439.939   622.061
# Asian        -18.6863     65.021     -0.287      0.774      -146.515   109.142
# Caucasian    -12.5025     56.681     -0.221      0.826      -123.935    98.930
# ==============================================================================
# Omnibus:                       28.829   Durbin-Watson:                   1.946
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.395
# Skew:                           0.581   Prob(JB):                     1.13e-06
# Kurtosis:                       2.460   Cond. No.                         4.39
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Answer: (If your answer is yes, interpret the results).  TODO

# %% [markdown]
# > ## Question 11.  Finally let's regress `Balance` on `Student`.  After running your linear regressions, do you have enough evidence to claim that students carry more balance than non-students?

# %%
# TODO
model = smf.ols(formula = 'Balance ~ IsStudent', data = df).fit()
model.summary()

# yes, coefficient is significant
# balance for students is $396 higher than those who are not students
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Balance   R-squared:                       0.067
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     28.62
# Date:                Sat, 20 May 2017   Prob (F-statistic):           1.49e-07
# Time:                        20:40:52   Log-Likelihood:                -3005.5
# No. Observations:                 400   AIC:                             6015.
# Df Residuals:                     398   BIC:                             6023.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    480.3694     23.434     20.499      0.000       434.300   526.439
# IsStudent    396.4556     74.104      5.350      0.000       250.771   542.140
# ==============================================================================
# Omnibus:                       20.866   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.920
# Skew:                           0.544   Prob(JB):                     1.74e-05
# Kurtosis:                       2.637   Cond. No.                         3.37
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Answer: (If your answer is yes, interpret the results).  TODO

# %% [markdown]
# > ## Question 12.  No let's consider the effect of `Student` and `Income` on `Balance` simultaneously.  Are all the coefficients significant?

# %%
# TODO
model = smf.ols(formula = 'Balance ~ IsStudent + Income', data = df).fit()
model.summary()

# coefficients are significant
#for each additional $1K in income, balance increases by $6
# on average, students have higher balance of $382 over balances for non-students
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Balance   R-squared:                       0.277
# Model:                            OLS   Adj. R-squared:                  0.274
# Method:                 Least Squares   F-statistic:                     76.22
# Date:                Sat, 20 May 2017   Prob (F-statistic):           9.64e-29
# Time:                        20:41:56   Log-Likelihood:                -2954.4
# No. Observations:                 400   AIC:                             5915.
# Df Residuals:                     397   BIC:                             5927.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    211.1430     32.457      6.505      0.000       147.333   274.952
# IsStudent    382.6705     65.311      5.859      0.000       254.272   511.069
# Income         5.9843      0.557     10.751      0.000         4.890     7.079
# ==============================================================================
# Omnibus:                      119.719   Durbin-Watson:                   1.951
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.617
# Skew:                           0.252   Prob(JB):                     7.44e-06
# Kurtosis:                       1.922   Cond. No.                         192.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Answer: (If your answer is yes, interpret the results).  TODO

# %% [markdown]
# > ## Question 13.  No let's consider the interaction effect of `Student` and `Income` on `Balance` simultaneously.  Are all the coefficients significant?  It they are, write down your regression model below

# %% [markdown]
# (First generate a new variable for the interaction term)

# %%
# TODO
model = smf.ols(formula = 'Balance ~ IsStudent + Income + IsStudent*Income', data = df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Balance   R-squared:                       0.280
# Model:                            OLS   Adj. R-squared:                  0.274
# Method:                 Least Squares   F-statistic:                     51.30
# Date:                Sat, 20 May 2017   Prob (F-statistic):           4.94e-28
# Time:                        20:44:19   Log-Likelihood:                -2953.7
# No. Observations:                 400   AIC:                             5915.
# Df Residuals:                     396   BIC:                             5931.
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# Intercept          200.6232     33.698      5.953      0.000       134.373   266.873
# IsStudent          476.6758    104.351      4.568      0.000       271.524   681.827
# Income               6.2182      0.592     10.502      0.000         5.054     7.382
# IsStudent:Income    -1.9992      1.731     -1.155      0.249        -5.403     1.404
# ==============================================================================
# Omnibus:                      107.788   Durbin-Watson:                   1.952
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.158
# Skew:                           0.228   Prob(JB):                     1.54e-05
# Kurtosis:                       1.941   Cond. No.                         309.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Answer: TODO
# # interaction is not significant
# # MINE SAYS NOT SIGNIFICANT, BUT OTHER VERSION **DOES**

# %% [markdown]
# > ## Question 14.  Is there any income level at which students and non-students on average carry same level of balance?

# %%
#Answer: TODO
d = 476/6.0
d
# Out:
# 79.33333333333333
